# %%
import json
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
import sklearn.cluster as cluster
import numpy as np

# %%
with open('data_dragos.json') as f:
    data = json.load(f)

index = 0
dataframe = pd.DataFrame(columns=["x","y","z"])
print(dataframe)
for line in data:
    gp = line['Gaze Position 3D'] ['gp3']
    dataframe.loc[index] = [gp[0],gp[1],gp[2]]
    index = index +1
# Out:
# Empty DataFrame
# Columns: [x, y, z]
# Index: []

# %%
kmeans = KMeans(n_clusters=4).fit(dataframe)
centroids = kmeans.cluster_centers_
print(centroids)
# Out:
# [[-3.82628012e+01 -3.85361446e+00  4.54864729e+02]
#  [-3.57188080e+03  1.37737200e+02  8.70360160e+03]
#  [ 3.81040455e+02  1.91860909e+02  3.17036682e+03]
#  [-5.70728745e-01 -1.59859190e+02  1.02476093e+03]]

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.scatter3D(dataframe['x'], dataframe['y'], dataframe['z'], c= kmeans.labels_.astype(float),alpha=0.3)
ax.scatter3D(centroids[:, 0], centroids[:, 1],centroids[:, 2], c='red', s=50)
plt.show()
